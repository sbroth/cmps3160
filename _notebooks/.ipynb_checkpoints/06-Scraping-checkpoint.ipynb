# %%
# Note you may have to install requests!  pip3 install requests

import requests
# These two things are for Pandas, it widens the notebook and lets us display data easily.
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# ## Simple API Call with Requests Library
#
# It may be good to look at the reference documentation for the [requests library](https://2.python-requests.org/en/master/user/quickstart/).
#
# First, let's have a look at the [GitHub API](https://developer.github.com/v3/).

# %%
r = requests.get('https://api.github.com/users/nmattei', timeout=10)
r.status_code
# Out:
# 200

# %%
r.headers['content-type']
# Out:
# 'application/json; charset=utf-8'

# %%
r.url
# Out:
# 'https://api.github.com/users/nmattei'

# %%
r.content
# Out:
# b'{"login":"nmattei","id":1206578,"node_id":"MDQ6VXNlcjEyMDY1Nzg=","avatar_url":"https://avatars.githubusercontent.com/u/1206578?v=4","gravatar_id":"","url":"https://api.github.com/users/nmattei","html_url":"https://github.com/nmattei","followers_url":"https://api.github.com/users/nmattei/followers","following_url":"https://api.github.com/users/nmattei/following{/other_user}","gists_url":"https://api.github.com/users/nmattei/gists{/gist_id}","starred_url":"https://api.github.com/users/nmattei/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/nmattei/subscriptions","organizations_url":"https://api.github.com/users/nmattei/orgs","repos_url":"https://api.github.com/users/nmattei/repos","events_url":"https://api.github.com/users/nmattei/events{/privacy}","received_events_url":"https://api.github.com/users/nmattei/received_events","type":"User","site_admin":false,"name":"Nicholas Mattei","company":"Tulane University","blog":"http://www.nickmattei.net","location":null,"email":null,"hireable":null,"bio":null,"twitter_username":null,"public_repos":13,"public_gists":0,"followers":20,"following":15,"created_at":"2011-11-19T15:38:51Z","updated_at":"2021-10-11T14:31:16Z"}'

# %%
r.json()
# Out:
# {'login': 'nmattei',
#  'id': 1206578,
#  'node_id': 'MDQ6VXNlcjEyMDY1Nzg=',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/1206578?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/nmattei',
#  'html_url': 'https://github.com/nmattei',
#  'followers_url': 'https://api.github.com/users/nmattei/followers',
#  'following_url': 'https://api.github.com/users/nmattei/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/nmattei/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/nmattei/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/nmattei/subscriptions',
#  'organizations_url': 'https://api.github.com/users/nmattei/orgs',
#  'repos_url': 'https://api.github.com/users/nmattei/repos',
#  'events_url': 'https://api.github.com/users/nmattei/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/nmattei/received_events',
#  'type': 'User',
#  'site_admin': False,
#  'name': 'Nicholas Mattei',
#  'company': 'Tulane University',
#  'blog': 'http://www.nickmattei.net',
#  'location': None,
#  'email': None,
#  'hireable': None,
#  'bio': None,
#  'twitter_username': None,
#  'public_repos': 13,
#  'public_gists': 0,
#  'followers': 20,
#  'following': 15,
#  'created_at': '2011-11-19T15:38:51Z',
#  'updated_at': '2021-10-11T14:31:16Z'}

# %% [markdown]
# ## Looking at HTTP Requests
#
# We'll try to get some data from Google.  Note that this is kind of against the TOS and we **should not do it this way in general -- Google has very [specific rules on their site](https://developers.google.com/custom-search/v1/).**

# %%
params = {'q':'Tulane University'}
r = requests.get('http://www.google.com/search', params = params, timeout=10)
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'http://www.google.com/search?q=Tulane+University'

# %%
r.headers['content-type']
# Out:
# 'text/html; charset=ISO-8859-1'

# %%
r.text
# Out:
# '<!doctype html><html lang="en"><head><meta charset="UTF-8"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Tulane University - Google Search</title><script nonce="pAHkKtwpFpazOGYlOWm/Zw==">(function(){\ndocument.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"===c||"q"===c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!==document.documentElement;a=a.parentElement)if("A"===a.tagName){a="1"===a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){\nvar a=window.performance;window.start=Date.now();a:{var b=window;if(a){var c=a.timing;if(c){var d=c.navigationStart,f=c.responseStart;if(f>d&&f<=window.start){window.start=f;b.wsrt=f-d;break a}}a.now&&(b.wsrt=Math.floor(a.now()))}}window.google=window.google||{};var h=function(g){g&&g.target.setAttribute("data-iml",Date.now())};document.documentElement.addEventListener("load",h,!0);google.rglh=function(){document.documentElement.removeEventListener("load",h,!0)};}).call(this);(function(){window.google.erd={sp:\'srp\',jsr:0,bv:1458};})();(function(){\nvar c=[],e=0;window.ping=function(b){-1==b.indexOf("&zx")&&(b+="&zx="+Date.now());var a=new Image,d=e++;c[d]=a;a.onerror=a.onload=a.onabort=function(){delete c[d]};a.src=b};}).call(this);</script><style>body{margin:0 auto;max-width:736px;padding:0 8px;}a{color:#1967D2;text-decoration:none;tap-highlight-color:rgba(0,0,0,.10)}a:visited{color:#4B11A8}a:hover{text-decoration:underline}img{border:0}html{font-family:Roboto,Helvetica Neue,Arial,sans-serif;font-size:14px;line-height:20px;text-size-adjust:100%;color:#3c4043;word-wrap:break-word;background-color:#fff}.bRsWnc{background-color:#fff;border-top:1px solid #dadce0;height:39px;overflow:hidden}.N6RWV{height:51px;overflow-scrolling:touch;overflow-x:auto;overflow-y:hidden}.Uv67qb{box-pack:justify;font-size:12px;line-height:37px;justify-content:space-between;justify-content:space-between}.Uv67qb a,.Uv67qb span{color:#70757a;display:block;flex:none;padding:0 16px;text-align:center;text-transform:uppercase;}span.OXXup{border-bottom:2px solid #4285f4;color:#4285f4;font-weight:bold}a.eZt8xd:visited{color:#70757a}.FElbsf{border-left:1px solid rgba(0,0,0,.12)}header article{overflow:visible}.Pg70bf{height:39px;display:box;display:flex;display:flex;width:100%}.H0PQec{position:relative;flex:1}.sbc{display:flex;width:100%}.Pg70bf input{margin:2px 4px 2px 8px;}.x{width:26px;color:#70757a;font:27px/38px arial, sans-serif;line-height:40px;}#qdClwb{flex:0 0 auto;width:39px;height:39px;border-bottom:0;padding:0;border-top-right-radius:8px;background-color:#1a73e8;border:1px solid #1558d6;background-image:url(...);}.sc{font-size:16px;position:absolute;top:39px;left:0;right:0;box-shadow:0px 2px 5px rgba(0,0,0,.2);z-index:2;background-color:#fff}.sc>div{padding:10px 10px;padding-left:16px;padding-left:14px;border-top:1px solid #dfe1e5}.scs{background-color:#f8f9fa;}.noHIxc{display:block;font-size:16px;padding:0 0 0 8px;flex:1;height:35px;outline:none;border:none;width:100%;-webkit-tap-highlight-color:rgba(0,0,0,.00);overflow:hidden;}.sbc input[type=text]{background:none}.sml .cOl4Id{display:none}.l{display:none}.sml header{background:none}.sml .l{display:block;padding:0 8px}.sml .l{letter-spacing:-1px;text-align:center;border-radius:2px 0 0 0;font:22px/36px Futura, Arial, sans-serif;font-smoothing:antialiased}.bz1lBb{background:#fff;border-radius:8px 8px 0 0;box-shadow:0 1px 6px rgba(32, 33, 36, 0.18);margin-top:10px}.KP7LCb{border-radius:0 0 8px 8px;box-shadow:0 2px 3px rgba(32, 33, 36, 0.18);margin-bottom:10px;overflow:hidden}.cOl4Id{letter-spacing:-1px;text-align:center;font:22pt Futura, Arial, sans-serif;height:37px;font-smoothing:antialiased;padding:10px 0 5px 0;}.cOl4Id span{display:inline-block}.S591j{height:1 ...

# %% [markdown]
# ## More Complicated with Parameters
#
# We'll look for some information from the [Apple ITunes API](https://affiliate.itunes.apple.com/resources/documentation/itunes-store-web-service-search-api/).

# %%
params = {'term' : "the+meters"}
r = requests.get('https://itunes.apple.com/search', params=params, timeout=10)
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://itunes.apple.com/search?term=the%2Bmeters'

# %%
r.json()
# Out:
# {'resultCount': 50,
#  'results': [{'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 59401239,
#    'trackId': 59401193,
#    'artistName': 'The Meters',
#    'collectionName': 'The Meters',
#    'trackName': 'Cissy Strut',
#    'collectionCensoredName': 'The Meters',
#    'trackCensoredName': 'Cissy Strut',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/cissy-strut/59401239?i=59401193&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/cissy-strut/59401239?i=59401193&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/2e/9b/85/2e9b8549-cea1-f64d-48b6-05770ec0a692/mzaf_5938744141518605358.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1969-05-01T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 12,
#    'trackNumber': 1,
#    'trackTimeMillis': 186853,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 59401239,
#    'trackId': 59401211,
#    'artistName': 'The Meters',
#    'collectionName': 'The Meters',
#    'trackName': 'Sophisticated Cissy',
#    'collectionCensoredName': 'The Meters',
#    'trackCensoredName': 'Sophisticated Cissy',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/sophisticated-cissy/59401239?i=59401211&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/sophisticated-cissy/59401239?i=59401211&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/47/cf/6f/47cf6f9b-8be5-c62e-3a7f-906fe934e050/mzaf_6739916060205453466.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1969-05-01T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 12,
#    'trackNumber': 6,
#    'trackTimeMillis': 176693,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 59401239,
#    'trackId': 59401197,
#    'artistName': 'The Meters',
#    'collectionName': 'The Meters',
#    'trackName': 'Here Comes the Meter Man',
#    'collectionCensoredName': 'The Meters',
#    'trackCensoredName': 'Here Comes the Meter Man',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/here-comes-the-meter-man/59401239?i=59401197&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/here-comes-the-meter-man/59401239?i=59401197&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/a4/bb/de/a4bbde73-25a3-b710-731b-9568d87239de/mzaf_1710190207997247095.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1969-05-01T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 12,
#    'trackNumber': 2,
#    'trackTimeMillis': 175200,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 59401239,
#    'trackId': 59401230,
#    'artistName': 'The Meters',
#    'collectionName': 'The Meters',
#    'trackName': 'Stormy',
#    'collectionCensoredName': 'The Meters',
#    'trackCensoredName': 'Stormy',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/stormy/59401239?i=59401230&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/stormy/59401239?i=59401230&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/41/c5/34/41c5347e-a7da-94fd-d367-428fa9c1bd4b/mzaf_13171770230824244123.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1969-05-01T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 12,
#    'trackNumber': 11,
#    'trackTimeMillis': 220533,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 59401239,
#    'trackId': 59401203,
#    'artistName': 'The Meters',
#    'collectionName': 'The Meters',
#    'trackName': 'Live Wire',
#    'collectionCensoredName': 'The Meters',
#    'trackCensoredName': 'Live Wire',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/live-wire/59401239?i=59401203&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/live-wire/59401239?i=59401203&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/b6/71/aa/b671aa6a-17d1-3005-1f09-5d207a0b2fa9/mzaf_10294193141812181674.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1969-05-01T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 12,
#    'trackNumber': 4,
#    'trackTimeMillis': 160403,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 59401239,
#    'trackId': 59401201,
#    'artistName': 'The Meters',
#    'collectionName': 'The Meters',
#    'trackName': 'Cardova',
#    'collectionCensoredName': 'The Meters',
#    'trackCensoredName': 'Cardova',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/cardova/59401239?i=59401201&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/cardova/59401239?i=59401201&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/ff/f3/1c/fff31ce1-a149-0cb9-cf65-7dc932af4313/mzaf_6640839964938037790.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1969-05-01T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 12,
#    'trackNumber': 3,
#    'trackTimeMillis': 275253,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 59401239,
#    'trackId': 59401236,
#    'artistName': 'The Meters',
#    'collectionName': 'The Meters',
#    'trackName': 'Sing a Simple Song',
#    'collectionCensoredName': 'The Meters',
#    'trackCensoredName': 'Sing a Simple Song',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/sing-a-simple-song/59401239?i=59401236&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/sing-a-simple-song/59401239?i=59401236&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/c4/32/86/c432868a-2d66-3616-9168-7061a7b68c8d/mzaf_1640392504893997050.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1969-05-01T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 12,
#    'trackNumber': 12,
#    'trackTimeMillis': 186573,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 59401239,
#    'trackId': 59401226,
#    'artistName': 'The Meters',
#    'collectionName': 'The Meters',
#    'trackName': 'Ann',
#    'collectionCensoredName': 'The Meters',
#    'trackCensoredName': 'Ann',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/ann/59401239?i=59401226&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/ann/59401239?i=59401226&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/64/a0/42/64a04216-f01b-0318-05dd-86157a169c73/mzaf_8274601214481846183.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1969-05-01T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 12,
#    'trackNumber': 10,
#    'trackTimeMillis': 166093,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 59401239,
#    'trackId': 59401217,
#    'artistName': 'The Meters',
#    'collectionName': 'The Meters',
#    'trackName': 'Ease Back',
#    'collectionCensoredName': 'The Meters',
#    'trackCensoredName': 'Ease Back',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/ease-back/59401239?i=59401217&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/ease-back/59401239?i=59401217&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/ca/c3/2f/cac32fc0-dda3-8b0a-2f08-091cb1faa4bb/mzaf_8853446333121395884.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1969-05-01T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 12,
#    'trackNumber': 7,
#    'trackTimeMillis': 194973,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 59401239,
#    'trackId': 59401220,
#    'artistName': 'The Meters',
#    'collectionName': 'The Meters',
#    'trackName': '6V6 La',
#    'collectionCensoredName': 'The Meters',
#    'trackCensoredName': '6V6 La',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/6v6-la/59401239?i=59401220&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/6v6-la/59401239?i=59401220&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/e9/b0/8f/e9b08f8d-7771-caa0-9def-1e76b4af0fb7/mzaf_8816323374863985866.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1969-05-01T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 12,
#    'trackNumber': 8,
#    'trackTimeMillis': 146093,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 59401239,
#    'trackId': 59401224,
#    'artistName': 'The Meters',
#    'collectionName': 'The Meters',
#    'trackName': "Sehorn's Farm",
#    'collectionCensoredName': 'The Meters',
#    'trackCensoredName': "Sehorn's Farm",
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/sehorns-farm/59401239?i=59401224&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/sehorns-farm/59401239?i=59401224&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/21/3b/42/213b42c7-adf6-b8fa-ac0e-8216d0b2aea2/mzaf_12453621347162848438.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1969-05-01T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 12,
#    'trackNumber': 9,
#    'trackTimeMillis': 151307,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 59401239,
#    'trackId': 59401208,
#    'artistName': 'The Meters',
#    'collectionName': 'The Meters',
#    'trackName': 'Art',
#    'collectionCensoredName': 'The Meters',
#    'trackCensoredName': 'Art',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/art/59401239?i=59401208&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/art/59401239?i=59401208&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/06/24/e9/0624e92a-86ee-58ba-008e-331f8b41516a/mzaf_866906782681212202.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music124/v4/9f/be/8a/9fbe8a82-b711-2594-c77d-c09c36f31598/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1969-05-01T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 12,
#    'trackNumber': 5,
#    'trackTimeMillis': 155107,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 337680302,
#    'collectionId': 1480012924,
#    'trackId': 1480012933,
#    'artistName': 'Harish Raghavan',
#    'collectionName': 'Calls for Action',
#    'trackName': 'The Meters (feat. Micah Thomas)',
#    'collectionCensoredName': 'Calls for Action',
#    'trackCensoredName': 'The Meters (feat. Micah Thomas)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/harish-raghavan/337680302?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/the-meters-feat-micah-thomas/1480012924?i=1480012933&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/the-meters-feat-micah-thomas/1480012924?i=1480012933&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/39/20/62/392062b0-7b64-36bc-c3d2-d415329b6e31/mzaf_1602503362520087944.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music113/v4/c4/fc/e7/c4fce75b-d9a2-a700-248c-aa8a9f3a8c2f/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music113/v4/c4/fc/e7/c4fce75b-d9a2-a700-248c-aa8a9f3a8c2f/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music113/v4/c4/fc/e7/c4fce75b-d9a2-a700-248c-aa8a9f3a8c2f/source/100x100bb.jpg',
#    'collectionPrice': 8.99,
#    'trackPrice': 1.29,
#    'releaseDate': '2019-11-08T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 15,
#    'trackNumber': 8,
#    'trackTimeMillis': 246133,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Jazz',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 59401414,
#    'trackId': 59401412,
#    'artistName': 'The Meters',
#    'collectionName': 'Fire On the Bayou',
#    'trackName': 'Mardi Gras Mambo',
#    'collectionCensoredName': 'Fire On the Bayou',
#    'trackCensoredName': 'Mardi Gras Mambo',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/mardi-gras-mambo/59401414?i=59401412&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/mardi-gras-mambo/59401414?i=59401412&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/dc/88/a9/dc88a94c-1842-bd6c-3eea-a485a964bf94/mzaf_13071949705644523911.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is5-ssl.mzstatic.com/image/thumb/Music115/v4/f8/4a/37/f84a378e-90e3-e17b-99f6-e925354dc089/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is5-ssl.mzstatic.com/image/thumb/Music115/v4/f8/4a/37/f84a378e-90e3-e17b-99f6-e925354dc089/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is5-ssl.mzstatic.com/image/thumb/Music115/v4/f8/4a/37/f84a378e-90e3-e17b-99f6-e925354dc089/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1975-01-01T08:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 11,
#    'trackNumber': 11,
#    'trackTimeMillis': 159200,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 213532006,
#    'trackId': 213532023,
#    'artistName': 'The Meters',
#    'collectionName': 'The Very Best of The Meters',
#    'trackName': 'Cissy Strut',
#    'collectionCensoredName': 'The Very Best of The Meters',
#    'trackCensoredName': 'Cissy Strut',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/cissy-strut/213532006?i=213532023&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/cissy-strut/213532006?i=213532023&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/59/19/24/5919243e-47c7-fdb4-82fd-bea61c2ef0b7/mzaf_3755831238467141085.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1995-02-28T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 16,
#    'trackNumber': 1,
#    'trackTimeMillis': 185227,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 213532006,
#    'trackId': 213532570,
#    'artistName': 'The Meters',
#    'collectionName': 'The Very Best of The Meters',
#    'trackName': "They All Ask'd for You (Remastered Single Version)",
#    'collectionCensoredName': 'The Very Best of The Meters',
#    'trackCensoredName': "They All Ask'd for You (Remastered Single Version)",
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/they-all-askd-for-you-remastered-single-version/213532006?i=213532570&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/they-all-askd-for-you-remastered-single-version/213532006?i=213532570&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/52/26/06/52260615-8db9-7030-fdd1-994eb7440012/mzaf_12503171507872868817.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1974-01-01T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 16,
#    'trackNumber': 15,
#    'trackTimeMillis': 250973,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 213532006,
#    'trackId': 213532266,
#    'artistName': 'The Meters',
#    'collectionName': 'The Very Best of The Meters',
#    'trackName': 'Hey Pocky a-Way (Remastered Single Version)',
#    'collectionCensoredName': 'The Very Best of The Meters',
#    'trackCensoredName': 'Hey Pocky a-Way (Remastered Single Version)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/hey-pocky-a-way-remastered-single-version/213532006?i=213532266&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/hey-pocky-a-way-remastered-single-version/213532006?i=213532266&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/c6/23/c0/c623c04b-59bc-2816-273a-576c657ff939/mzaf_9065557668220671057.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1997-06-10T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 16,
#    'trackNumber': 10,
#    'trackTimeMillis': 242173,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 59401178,
#    'trackId': 59401159,
#    'artistName': 'The Meters',
#    'collectionName': 'Rejuvenation',
#    'trackName': 'Hey Pocky A-way',
#    'collectionCensoredName': 'Rejuvenation',
#    'trackCensoredName': 'Hey Pocky A-way',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/hey-pocky-a-way/59401178?i=59401159&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/hey-pocky-a-way/59401178?i=59401159&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/b7/44/41/b74441a2-cfcd-7789-d0d3-44b1ae97d502/mzaf_989657148355291264.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is5-ssl.mzstatic.com/image/thumb/Music125/v4/86/76/9e/86769ebf-ae80-2f4e-dc56-923ea3db005a/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is5-ssl.mzstatic.com/image/thumb/Music125/v4/86/76/9e/86769ebf-ae80-2f4e-dc56-923ea3db005a/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is5-ssl.mzstatic.com/image/thumb/Music125/v4/86/76/9e/86769ebf-ae80-2f4e-dc56-923ea3db005a/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1974-07-01T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 9,
#    'trackNumber': 6,
#    'trackTimeMillis': 246867,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 213532006,
#    'trackId': 213532093,
#    'artistName': 'The Meters',
#    'collectionName': 'The Very Best of The Meters',
#    'trackName': 'Look-Ka Py Py',
#    'collectionCensoredName': 'The Very Best of The Meters',
#    'trackCensoredName': 'Look-Ka Py Py',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/look-ka-py-py/213532006?i=213532093&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/look-ka-py-py/213532006?i=213532093&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/f0/a9/4f/f0a94f0a-0578-28a4-a8f6-c7b84d3c5763/mzaf_15899369747875462975.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1969-12-01T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 16,
#    'trackNumber': 4,
#    'trackTimeMillis': 198333,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 213532006,
#    'trackId': 213532135,
#    'artistName': 'The Meters',
#    'collectionName': 'The Very Best of The Meters',
#    'trackName': 'Tippi-Toes',
#    'collectionCensoredName': 'The Very Best of The Meters',
#    'trackCensoredName': 'Tippi-Toes',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/tippi-toes/213532006?i=213532135&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/tippi-toes/213532006?i=213532135&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/99/17/67/9917677f-a0bd-5236-e6df-223318175bd6/mzaf_10668384990763370134.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1970-01-01T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 16,
#    'trackNumber': 6,
#    'trackTimeMillis': 146827,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 59401414,
#    'trackId': 59401366,
#    'artistName': 'The Meters',
#    'collectionName': 'Fire On the Bayou',
#    'trackName': 'Fire On the Bayou',
#    'collectionCensoredName': 'Fire On the Bayou',
#    'trackCensoredName': 'Fire On the Bayou',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/fire-on-the-bayou/59401414?i=59401366&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/fire-on-the-bayou/59401414?i=59401366&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/9f/39/93/9f39939a-8f26-0ea9-1251-0b93cccd5944/mzaf_10472334425240460686.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is5-ssl.mzstatic.com/image/thumb/Music115/v4/f8/4a/37/f84a378e-90e3-e17b-99f6-e925354dc089/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is5-ssl.mzstatic.com/image/thumb/Music115/v4/f8/4a/37/f84a378e-90e3-e17b-99f6-e925354dc089/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is5-ssl.mzstatic.com/image/thumb/Music115/v4/f8/4a/37/f84a378e-90e3-e17b-99f6-e925354dc089/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1975-01-01T08:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 11,
#    'trackNumber': 2,
#    'trackTimeMillis': 250067,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 213532006,
#    'trackId': 213532499,
#    'artistName': 'The Meters',
#    'collectionName': 'The Very Best of The Meters',
#    'trackName': 'Fire On the Bayou (Remastered)',
#    'collectionCensoredName': 'The Very Best of The Meters',
#    'trackCensoredName': 'Fire On the Bayou (Remastered)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/fire-on-the-bayou-remastered/213532006?i=213532499&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/fire-on-the-bayou-remastered/213532006?i=213532499&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/ec/04/df/ec04dfd3-bb23-11b0-4479-d46f4f934f85/mzaf_9999222183876522854.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1997-06-10T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 16,
#    'trackNumber': 14,
#    'trackTimeMillis': 247000,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 213532006,
#    'trackId': 213532251,
#    'artistName': 'The Meters',
#    'collectionName': 'The Very Best of The Meters',
#    'trackName': 'People Say (Remastered)',
#    'collectionCensoredName': 'The Very Best of The Meters',
#    'trackCensoredName': 'People Say (Remastered)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/people-say-remastered/213532006?i=213532251&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/people-say-remastered/213532006?i=213532251&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/6d/c3/d6/6dc3d6f4-a647-0832-c037-5eae783de79a/mzaf_14625713980756408820.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1997-06-10T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 16,
#    'trackNumber': 9,
#    'trackTimeMillis': 316373,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 213532006,
#    'trackId': 213532085,
#    'artistName': 'The Meters',
#    'collectionName': 'The Very Best of The Meters',
#    'trackName': 'Sophisticated Cissy',
#    'collectionCensoredName': 'The Very Best of The Meters',
#    'trackCensoredName': 'Sophisticated Cissy',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/sophisticated-cissy/213532006?i=213532085&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/sophisticated-cissy/213532006?i=213532085&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/d9/58/3b/d9583b36-24e8-99fd-4295-93823541214b/mzaf_6455413228173279892.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1995-02-28T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 16,
#    'trackNumber': 3,
#    'trackTimeMillis': 175400,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 213532006,
#    'trackId': 213532059,
#    'artistName': 'The Meters',
#    'collectionName': 'The Very Best of The Meters',
#    'trackName': 'Live Wire',
#    'collectionCensoredName': 'The Very Best of The Meters',
#    'trackCensoredName': 'Live Wire',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/live-wire/213532006?i=213532059&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/live-wire/213532006?i=213532059&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/1d/f1/42/1df142ec-8fb7-5c7b-d60a-696c6f34740c/mzaf_8126574396270232094.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1995-02-28T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 16,
#    'trackNumber': 2,
#    'trackTimeMillis': 160000,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 213532006,
#    'trackId': 213532201,
#    'artistName': 'The Meters',
#    'collectionName': 'The Very Best of The Meters',
#    'trackName': 'Cabbage Alley (Remastered)',
#    'collectionCensoredName': 'The Very Best of The Meters',
#    'trackCensoredName': 'Cabbage Alley (Remastered)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/cabbage-alley-remastered/213532006?i=213532201&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/cabbage-alley-remastered/213532006?i=213532201&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/8c/2d/19/8c2d1940-0466-e0c9-9890-027bf8fa94b2/mzaf_16453104206129055837.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1972-01-01T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 16,
#    'trackNumber': 8,
#    'trackTimeMillis': 210200,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 213532006,
#    'trackId': 213532101,
#    'artistName': 'The Meters',
#    'collectionName': 'The Very Best of The Meters',
#    'trackName': 'Pungee',
#    'collectionCensoredName': 'The Very Best of The Meters',
#    'trackCensoredName': 'Pungee',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/pungee/213532006?i=213532101&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/pungee/213532006?i=213532101&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/32/72/14/32721489-d56c-9997-22e9-15c4f0c09d3a/mzaf_2422038285086592358.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1969-12-01T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 16,
#    'trackNumber': 5,
#    'trackTimeMillis': 179360,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 213532006,
#    'trackId': 213532326,
#    'artistName': 'The Meters',
#    'collectionName': 'The Very Best of The Meters',
#    'trackName': 'Jungle Man (Remastered)',
#    'collectionCensoredName': 'The Very Best of The Meters',
#    'trackCensoredName': 'Jungle Man (Remastered)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/jungle-man-remastered/213532006?i=213532326&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/jungle-man-remastered/213532006?i=213532326&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/64/85/99/64859929-7bdb-046d-82bb-253183b59c6e/mzaf_82369468580301499.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1997-06-10T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 16,
#    'trackNumber': 12,
#    'trackTimeMillis': 205400,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 213532006,
#    'trackId': 213532411,
#    'artistName': 'The Meters',
#    'collectionName': 'The Very Best of The Meters',
#    'trackName': 'Out In the Country (Remastered)',
#    'collectionCensoredName': 'The Very Best of The Meters',
#    'trackCensoredName': 'Out In the Country (Remastered)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/out-in-the-country-remastered/213532006?i=213532411&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/out-in-the-country-remastered/213532006?i=213532411&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/d6/af/11/d6af118b-dde1-a2ba-15cd-e153cc0c43a1/mzaf_10189657138796812619.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1975-01-01T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 16,
#    'trackNumber': 13,
#    'trackTimeMillis': 215000,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 213532006,
#    'trackId': 213532143,
#    'artistName': 'The Meters',
#    'collectionName': 'The Very Best of The Meters',
#    'trackName': 'Soul Island (Remastered)',
#    'collectionCensoredName': 'The Very Best of The Meters',
#    'trackCensoredName': 'Soul Island (Remastered)',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/soul-island-remastered/213532006?i=213532143&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/soul-island-remastered/213532006?i=213532143&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/ff/e4/f6/ffe4f6a2-5869-9385-18a6-0d41a05664c5/mzaf_15732099005436325848.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1972-01-01T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 16,
#    'trackNumber': 7,
#    'trackTimeMillis': 190667,
# ...
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 9,
#    'trackNumber': 5,
#    'trackTimeMillis': 206933,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 159362708,
#    'trackId': 159362711,
#    'artistName': 'The Meters',
#    'collectionName': 'Look-Ka Py Py',
#    'trackName': 'Rigor Mortis',
#    'collectionCensoredName': 'Look-Ka Py Py',
#    'trackCensoredName': 'Rigor Mortis',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/rigor-mortis/159362708?i=159362711&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/rigor-mortis/159362708?i=159362711&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/ff/8e/ed/ff8eeddf-49d5-5186-9950-a586027580c2/mzaf_10093093157332281063.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is2-ssl.mzstatic.com/image/thumb/Music/v4/83/60/4a/83604aac-0e65-066c-8b73-24d517db5afb/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Music/v4/83/60/4a/83604aac-0e65-066c-8b73-24d517db5afb/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Music/v4/83/60/4a/83604aac-0e65-066c-8b73-24d517db5afb/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1969-12-01T08:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 12,
#    'trackNumber': 2,
#    'trackTimeMillis': 156493,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 159362708,
#    'trackId': 159362723,
#    'artistName': 'The Meters',
#    'collectionName': 'Look-Ka Py Py',
#    'trackName': 'Oh, Calcutta!',
#    'collectionCensoredName': 'Look-Ka Py Py',
#    'trackCensoredName': 'Oh, Calcutta!',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/oh-calcutta/159362708?i=159362723&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/oh-calcutta/159362708?i=159362723&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/41/df/55/41df557c-4d4d-599a-7bb9-d830f0edb78a/mzaf_12047423338051330931.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is2-ssl.mzstatic.com/image/thumb/Music/v4/83/60/4a/83604aac-0e65-066c-8b73-24d517db5afb/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Music/v4/83/60/4a/83604aac-0e65-066c-8b73-24d517db5afb/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Music/v4/83/60/4a/83604aac-0e65-066c-8b73-24d517db5afb/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1969-12-01T08:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 12,
#    'trackNumber': 9,
#    'trackTimeMillis': 164000,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 59401178,
#    'trackId': 59401130,
#    'artistName': 'The Meters',
#    'collectionName': 'Rejuvenation',
#    'trackName': 'Love Is for Me',
#    'collectionCensoredName': 'Rejuvenation',
#    'trackCensoredName': 'Love Is for Me',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/love-is-for-me/59401178?i=59401130&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/love-is-for-me/59401178?i=59401130&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/4e/8c/b3/4e8cb30e-b353-04a4-04e8-cb185eaa7e8e/mzaf_493236858507092641.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is5-ssl.mzstatic.com/image/thumb/Music125/v4/86/76/9e/86769ebf-ae80-2f4e-dc56-923ea3db005a/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is5-ssl.mzstatic.com/image/thumb/Music125/v4/86/76/9e/86769ebf-ae80-2f4e-dc56-923ea3db005a/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is5-ssl.mzstatic.com/image/thumb/Music125/v4/86/76/9e/86769ebf-ae80-2f4e-dc56-923ea3db005a/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1974-07-01T07:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 9,
#    'trackNumber': 2,
#    'trackTimeMillis': 235493,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 159362708,
#    'trackId': 159362714,
#    'artistName': 'The Meters',
#    'collectionName': 'Look-Ka Py Py',
#    'trackName': 'Thinking',
#    'collectionCensoredName': 'Look-Ka Py Py',
#    'trackCensoredName': 'Thinking',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/thinking/159362708?i=159362714&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/thinking/159362708?i=159362714&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/96/a9/72/96a972cc-0742-c5a2-915c-05eda1fd42b3/mzaf_8888105825684370778.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is2-ssl.mzstatic.com/image/thumb/Music/v4/83/60/4a/83604aac-0e65-066c-8b73-24d517db5afb/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Music/v4/83/60/4a/83604aac-0e65-066c-8b73-24d517db5afb/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Music/v4/83/60/4a/83604aac-0e65-066c-8b73-24d517db5afb/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1969-12-01T08:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 12,
#    'trackNumber': 4,
#    'trackTimeMillis': 100827,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 56763785,
#    'trackId': 56763787,
#    'artistName': 'The Meters',
#    'collectionName': 'Funkify Your Life: The Meters Anthology',
#    'trackName': 'Cissy Strut',
#    'collectionCensoredName': 'Funkify Your Life: The Meters Anthology',
#    'trackCensoredName': 'Cissy Strut',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/cissy-strut/56763785?i=56763787&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/cissy-strut/56763785?i=56763787&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/fc/69/79/fc697908-e272-5c80-aa09-fcd2d206bd4c/mzaf_3442304459270761071.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/54/0a/ca/540acaa2-cb75-d5c6-6dc8-761bfa1c810a/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/54/0a/ca/540acaa2-cb75-d5c6-6dc8-761bfa1c810a/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/54/0a/ca/540acaa2-cb75-d5c6-6dc8-761bfa1c810a/source/100x100bb.jpg',
#    'collectionPrice': 29.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1995-02-28T12:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 43,
#    'trackNumber': 1,
#    'trackTimeMillis': 185227,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 159362708,
#    'trackId': 159362719,
#    'artistName': 'The Meters',
#    'collectionName': 'Look-Ka Py Py',
#    'trackName': "Yeah You're Right",
#    'collectionCensoredName': 'Look-Ka Py Py',
#    'trackCensoredName': "Yeah You're Right",
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/yeah-youre-right/159362708?i=159362719&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/yeah-youre-right/159362708?i=159362719&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/6c/83/43/6c8343a7-657d-c294-e3b2-cf56678c9420/mzaf_2699308086127898288.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is2-ssl.mzstatic.com/image/thumb/Music/v4/83/60/4a/83604aac-0e65-066c-8b73-24d517db5afb/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Music/v4/83/60/4a/83604aac-0e65-066c-8b73-24d517db5afb/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Music/v4/83/60/4a/83604aac-0e65-066c-8b73-24d517db5afb/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1969-12-01T08:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 12,
#    'trackNumber': 7,
#    'trackTimeMillis': 164800,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 159362708,
#    'trackId': 159362713,
#    'artistName': 'The Meters',
#    'collectionName': 'Look-Ka Py Py',
#    'trackName': 'Pungee',
#    'collectionCensoredName': 'Look-Ka Py Py',
#    'trackCensoredName': 'Pungee',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/pungee/159362708?i=159362713&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/pungee/159362708?i=159362713&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/25/7b/cd/257bcdb1-2d5d-07ab-8218-027d986a0aa6/mzaf_14530591828686378542.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is2-ssl.mzstatic.com/image/thumb/Music/v4/83/60/4a/83604aac-0e65-066c-8b73-24d517db5afb/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Music/v4/83/60/4a/83604aac-0e65-066c-8b73-24d517db5afb/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Music/v4/83/60/4a/83604aac-0e65-066c-8b73-24d517db5afb/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1969-12-01T08:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 12,
#    'trackNumber': 3,
#    'trackTimeMillis': 179973,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 159362708,
#    'trackId': 159362721,
#    'artistName': 'The Meters',
#    'collectionName': 'Look-Ka Py Py',
#    'trackName': 'Little Old Money Maker',
#    'collectionCensoredName': 'Look-Ka Py Py',
#    'trackCensoredName': 'Little Old Money Maker',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/little-old-money-maker/159362708?i=159362721&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/little-old-money-maker/159362708?i=159362721&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/ce/ef/af/ceefaf16-d827-e1ee-4410-30e683200fb2/mzaf_2837618397388430687.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is2-ssl.mzstatic.com/image/thumb/Music/v4/83/60/4a/83604aac-0e65-066c-8b73-24d517db5afb/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Music/v4/83/60/4a/83604aac-0e65-066c-8b73-24d517db5afb/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Music/v4/83/60/4a/83604aac-0e65-066c-8b73-24d517db5afb/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1969-12-01T08:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 12,
#    'trackNumber': 8,
#    'trackTimeMillis': 161027,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 159362708,
#    'trackId': 159362727,
#    'artistName': 'The Meters',
#    'collectionName': 'Look-Ka Py Py',
#    'trackName': "9 'Til 5",
#    'collectionCensoredName': 'Look-Ka Py Py',
#    'trackCensoredName': "9 'Til 5",
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/9-til-5/159362708?i=159362727&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/9-til-5/159362708?i=159362727&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/36/56/f6/3656f616-3ed2-467c-a6c2-2a2159e01c3b/mzaf_10574257858149356864.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is2-ssl.mzstatic.com/image/thumb/Music/v4/83/60/4a/83604aac-0e65-066c-8b73-24d517db5afb/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Music/v4/83/60/4a/83604aac-0e65-066c-8b73-24d517db5afb/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Music/v4/83/60/4a/83604aac-0e65-066c-8b73-24d517db5afb/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1969-12-01T08:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 12,
#    'trackNumber': 11,
#    'trackTimeMillis': 168867,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 7314214,
#    'collectionId': 159362708,
#    'trackId': 159362731,
#    'artistName': 'The Meters',
#    'collectionName': 'Look-Ka Py Py',
#    'trackName': 'Dry Spell',
#    'collectionCensoredName': 'Look-Ka Py Py',
#    'trackCensoredName': 'Dry Spell',
#    'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/dry-spell/159362708?i=159362731&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/dry-spell/159362708?i=159362731&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/69/6d/82/696d82f0-819d-af4a-fd54-385d2ccaa5e3/mzaf_16056019491639866026.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is2-ssl.mzstatic.com/image/thumb/Music/v4/83/60/4a/83604aac-0e65-066c-8b73-24d517db5afb/source/30x30bb.jpg',
#    'artworkUrl60': 'https://is2-ssl.mzstatic.com/image/thumb/Music/v4/83/60/4a/83604aac-0e65-066c-8b73-24d517db5afb/source/60x60bb.jpg',
#    'artworkUrl100': 'https://is2-ssl.mzstatic.com/image/thumb/Music/v4/83/60/4a/83604aac-0e65-066c-8b73-24d517db5afb/source/100x100bb.jpg',
#    'collectionPrice': 9.99,
#    'trackPrice': 1.29,
#    'releaseDate': '1969-12-01T08:00:00Z',
#    'collectionExplicitness': 'notExplicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 12,
#    'trackNumber': 12,
#    'trackTimeMillis': 149093,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'R&B/Soul',
#    'isStreamable': True}]}

# %%
r.url
# Out:
# 'https://itunes.apple.com/search?term=the%2Bmeters'

# %% [markdown]
# We can do lots of parameters in the payload like [this](https://2.python-requests.org/en/master/user/quickstart/).

# %%
params = {'term' : "the+meters", 'entity' : 'album'}
r = requests.get('https://itunes.apple.com/search', params=params, timeout=10)
r.status_code
# Out:
# 200

# %%
r.url
# Out:
# 'https://itunes.apple.com/search?term=the%2Bmeters&entity=album'

# %%
x = r.json()

# %%
type(x['results'][0])
# Out:
# dict

# %% [markdown]
# ## Converting the returned JSON to an object!

# %%
import json

# %%
data = json.loads(r.content)

# %%
data.keys()
# Out:
# dict_keys(['resultCount', 'results'])

# %%
type(data['results'])
# Out:
# list

# %%
type(data['results'][1])
# Out:
# dict

# %%
data['results'][1]
# Out:
# {'wrapperType': 'collection',
#  'collectionType': 'Album',
#  'artistId': 7314214,
#  'collectionId': 213532006,
#  'amgArtistId': 4907,
#  'artistName': 'The Meters',
#  'collectionName': 'The Very Best of The Meters',
#  'collectionCensoredName': 'The Very Best of The Meters',
#  'artistViewUrl': 'https://music.apple.com/us/artist/the-meters/7314214?uo=4',
#  'collectionViewUrl': 'https://music.apple.com/us/album/the-very-best-of-the-meters/213532006?uo=4',
#  'artworkUrl60': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/60x60bb.jpg',
#  'artworkUrl100': 'https://is1-ssl.mzstatic.com/image/thumb/Music/v4/ec/27/68/ec2768aa-ca30-a3d1-b3a5-f485d6e0ec35/source/100x100bb.jpg',
#  'collectionPrice': 9.99,
#  'collectionExplicitness': 'notExplicit',
#  'trackCount': 16,
#  'copyright': '℗ 2005 Warner Strategic Marketing',
#  'country': 'USA',
#  'currency': 'USD',
#  'releaseDate': '2005-03-29T08:00:00Z',
#  'primaryGenreName': 'R&B/Soul'}

# %%
data['results'][1].keys()
# Out:
# dict_keys(['wrapperType', 'collectionType', 'artistId', 'collectionId', 'amgArtistId', 'artistName', 'collectionName', 'collectionCensoredName', 'artistViewUrl', 'collectionViewUrl', 'artworkUrl60', 'artworkUrl100', 'collectionPrice', 'collectionExplicitness', 'trackCount', 'copyright', 'country', 'currency', 'releaseDate', 'primaryGenreName'])

# %% [markdown]
# ## Using Beautiful Soup to Parse a Webpage.
#
# The [beautifulsoup4 documentation](https://www.crummy.com/software/BeautifulSoup/).

# %%
# Grab the course webpage.
import requests
from bs4 import BeautifulSoup

r = requests.get('https://nmattei.github.io/cmps3160/schedule/')

root = BeautifulSoup( r.content )

# %%
r.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n  <!-- Beautiful Jekyll | MIT license | Copyright Dean Attali 2016 -->\n  <head>\n  <meta charset="utf-8" />\n  <meta http-equiv="X-UA-Compatible" content="IE=edge">\n  <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, viewport-fit=cover">\n\n  <title>Fall 2021 Schedule</title>\n\n  <meta name="author" content="Nicholas Mattei" />\n\n  \n\n  <link rel="alternate" type="application/rss+xml" title="CMPS 3160 Intro. to Data Science - Intro to Data Science - Fall 2020" href="https://nmattei.github.io/cmps3160/feed.xml" />\n\n  \n\n  \n\n  \n\n\n  \n    \n      \n  <link rel="stylesheet" href="//maxcdn.bootstrapcdn.com/font-awesome/4.6.0/css/font-awesome.min.css" />\n\n\n    \n  \n\n  \n    \n      <link rel="stylesheet" href="/cmps3160/css/bootstrap.min.css" />\n    \n      <link rel="stylesheet" href="/cmps3160/css/bootstrap-social.css" />\n    \n      <link rel="stylesheet" href="/cmps3160/css/main.css" />\n    \n  \n\n  \n    \n      <link rel="stylesheet" href="//fonts.googleapis.com/css?family=Lora:400,700,400italic,700italic" />\n    \n      <link rel="stylesheet" href="//fonts.googleapis.com/css?family=Open+Sans:300italic,400italic,600italic,700italic,800italic,400,300,600,700,800" />\n    \n  \n\n  \n\n  \n\n  \n\n    <!-- Facebook OpenGraph tags -->\n  \n\n  \n  <meta property="og:title" content="Fall 2021 Schedule" />\n  \n\n   \n  <meta property="og:description" content="## Important Resources for the Semester: * [Link to the Git Repo for the Course!](https://github.com/nmattei/cmps3160) * For a detailed list of assignments, learning time, and grading rubrics, pleasee go to the [Assignments Page.](/cmps3160/assignments/) * **While I make every effort to keep these tables up to date, if there is ever...">\n  \n\n\n  <meta property="og:type" content="website" />\n\n  \n  <meta property="og:url" content="https://nmattei.github.io/cmps3160/schedule/" />\n  <link rel="canonical" href="https://nmattei.github.io/cmps3160/schedule/" />\n  \n\n  \n\n\n  <!-- Twitter summary cards -->\n  <meta name="twitter:card" content="summary" />\n  <meta name="twitter:site" content="@" />\n  <meta name="twitter:creator" content="@" />\n\n  \n  <meta name="twitter:title" content="Fall 2021 Schedule" />\n  \n\n  \n  <meta name="twitter:description" content="## Important Resources for the Semester: * [Link to the Git Repo for the Course!](https://github.com/nmattei/cmps3160) * For a detailed list of assignments, learning time, and grading rubrics, pleasee go to the [Assignments Page.](/cmps3160/assignments/) * **While I make every effort to keep these tables up to date, if there is ever...">\n  \n\n  \n\n  \n\n  \n\n</head>\n\n\n  <body>\n\n    \n\n  \n    <nav class="navbar navbar-default navbar-fixed-top navbar-custom">\n  <div class="container-fluid">\n    <div class="navbar-header">\n      <button type="button" class="navbar-toggle" data-toggle="collapse" data-target="#main-navbar">\n        <span class="sr-only">Toggle navigation</span>\n        <span class="icon-bar"></span>\n        <span class="icon-bar"></span>\n        <span class="icon-bar"></span>\n      </button><a class="navbar-brand" href="https://nmattei.github.io/cmps3160">CMPS 3160 Intro. to Data Science</a></div>\n\n    <div class="collapse navbar-collapse" id="main-navbar">\n      <ul class="nav navbar-nav navbar-right">\n          <li><a href="/cmps3160/syllabus">Syllabus</a></li>\n          <li><a href="/cmps3160/schedule">Schedule</a></li>\n          <li><a href="/cmps3160/assignments">Assignments</a></li>\n          <li><a href="/cmps3160/projects/FinalTutorial">Final Tutorial</a></li>\n          <li><a href="/cmps3160/service">Service Learning</a></li>\n          <li><a href="/cmps3160/resources">Links & Resources</a></li></ul>\n    </div>\n\n\t\n\n  </div>\n</nav>\n\n\n    <!-- TODO this file has become a mess, refactor it -->\n\n\n\n\n\n<header class="header-section ">\n\n<div class="intro-hea ...

# %%
root.find("table")

# %%
root.find("table").findAll("a")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_36/3876490026.py in <module>
# ----> 1 root.find("table").findAll("a")
#
# AttributeError: 'NoneType' object has no attribute 'findAll'

# %% [markdown]
# ## Trying out some Regular Expressions.

# %%
import re
# Find the index in the raw HTML where we first mention CMPS3160

# Note we use the r to make sure special flags get used correctly.

r = requests.get('https://nmattei.github.io/cmps3160/syllabus/')
match = re.search(r'CMPS 3160', r.text)
print(match.start())
# Out:
# 460

# %%
r.text[390:500]
# Out:
# 'ei" />\n\n  \n\n  <link rel="alternate" type="application/rss+xml" title="CMPS 3160 Intro. to Data Science - Intro'

# %%
# Does the start match?
match = re.match(r'CMPS 3160', r.text)
print(match)

# %%
# Iterate over all occurances and print a few characters.
for m in re.finditer(r'CMPS 3160', r.text):
    print(r.text[m.start()-50:m.start()+50])

# %%
# Find them all.
match = re.findall(r'CMPS 3160', r.text)
print(match)

# %%
# More complicated RegExes - Groups
regex = r'\s*([Uu]niversity)\s([Oo]f)\s(\w{3,})'

text = ''' The university of kentucky is the best
            basketball team and an ok university. and University of North CC
            The University Of Kentucky can be put in 
            some weird capitalization and University of Ken spelled wrong'''
m = re.search( regex, text)
print(m.groups())

# %%
# Find all
print(re.findall(regex, text))

# %%
# Named Groups.
regex = r'\s*([Uu]niversity)\s([Oo]f)\s(?P<school>\w{3,})'
text = ''' The university of kentucky is the best University of Lousiana
            basketball team and an ok university.
            The University Of Kentucky can be put in 
            some weird capitalization'''
m = re.search( regex, text)
print(m.groupdict())

# %%
# Find all named groups

# Named Groups.
regex = r'\s*([Uu]niversity)\s([Oo]f)\s(?P<school>\w{3,})'
text = ''' The university of kentucky is the best
            basketball team and an ok university.
            The University Of Kentucky can be put in 
            some weird capitalization.  And Kentucky is much better than
            the University of Mississippi.'''
for m in re.finditer(regex, text):
    print(m.groupdict())

# %%
'abcabcabc'.replace('a', 'X')

# %%
text = 'I love Introduction to Data Science'
re.sub(r'Data Science', r'Schmada Schmience', text)

# %%
re.sub(r'(\w+)\s([Ss]cience)', r'\2 \1hmience', text)

# %% [markdown]
# ## Downloadning All the ... PDFs from the course website.
#
# Using beautiful soup and some regular expressions.

# %%
import re
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse
from urllib.parse import urljoin
import os
import pathlib

# %%
# HTTP GET request sent to the URL url
# We're going to use last year's website as it's got direct links...
r = requests.get( "https://nmattei.github.io/cmps3160/schedule/" )

# Use BeautifulSoup to parse the GET response
root = BeautifulSoup( r.content )
lnks = root.find("table").findAll("a")
lnks

# %% [markdown]
# Let's do the easier one first and download all the `.ipynb` from the webpage.  We'll get into why this is easier in a second...

# %%
# Cycle through the href for each anchor, checking
# to see if it's an ipynb link or not
notebooks = []
for lnk in lnks:
    href = lnk['href']
    # If it's a PDF/PPTX link, queue a download   
    if href.lower().endswith(('ipynb')):
        notebooks.append(href)
        print("{} is a Link to {}".format(lnk.contents,lnk['href']))
print(notebooks)

# %%
# Download all the files to whatever you're running notebook from.

# Be careful for href!

for i, href in enumerate(notebooks):
    print("Downloading... {}".format(href))
    rd = requests.get(href, stream=True)
    
    # Write the downloaded object to a file -- first we should make a directory for it..
    outputdir = os.path.join(os.getcwd(), "downloaded")
    os.makedirs(outputdir, exist_ok=True)
    
    # Note because the href is a path we have to just get the filename!
    outfile = os.path.join(outputdir, href.split("/")[-1])
    print("Writing: ",outfile)
    with open(outfile, 'wb') as f:
        f.write(rd.content)

# %% [markdown]
# Let's do this more complicated and try to grab all the PDF's...
#
# First thing to note is that the PDFs have it in the name but not the target and they're hosted on GOOGLE! -- so this doesn't really work :-(

# %%
# We can go check, we get a google drive directory...

r = requests.get( "https://drive.google.com/drive/u/1/folders/1uGrhWzhXbiqoChTK0fQXg340X319REks" )

# Use BeautifulSoup to parse the GET response
root = BeautifulSoup( r.content )
#lnks = root.find("table").findAll("a")
#lnks
root.content

# %%
# We have all google links so we need to check the tags to see if they contain PDF!
pdfs = []
for lnk in lnks:
    if 'pdf' in lnk.contents[0].lower():
        print("{} is a PDF Link to {}".format(lnk.contents,lnk['href']))
        pdfs.append(lnk['href'])
print(pdfs)

# %%
# Note that google doens't make this easy... sorry, you have to do a little kung fu...
# Format is: https://drive.google.com/u/1/uc?id=ID&export=download
download_links = []
for c in pdfs:
    fid = c.split("/")[-2]
    download_links.append("https://drive.google.com/u/1/uc?id={}&export=download".format(fid))
print(download_links)
